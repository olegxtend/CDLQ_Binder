# %% [markdown]
# # Test Binder environment setup

# %% [markdown]
# This notebook was part of [DWave's CDL bootcamp 2021 workshop](https://github.com/dwave-training/cdl_2021_python)

# %% [markdown]
# # 1. Import packages

# %%
from dwave.system import DWaveSampler, EmbeddingComposite
from collections import defaultdict
import networkx as nx
import dwave.inspector as inspector

# %% [markdown]
# # 2. Set up the problem
# # Create empty graph

# %%
G = nx.Graph()

# %% [markdown]
# # Add edges to the graph (also adds nodes)

# %%
G.add_edges_from([('a', 'b'), ('b', 'c'), ('b', 'd'), ('c', 'd'), ('c', 'f'), ('d', 'f'), ('d', 'e'), ('e', 'f')])

# %% [markdown]
# # ------- Set up our QUBO dictionary -------
# # Initialize our Q matrix

# %%
Q = defaultdict(int)

# %% [markdown]
# # Update Q matrix for every edge in the graph

# %%
for i, j in G.edges:
    Q[(i,i)]+= -1
    Q[(j,j)]+= -1
    Q[(i,j)]+= 2

# %% [markdown]
# # 3. Instantiate a solver
# ##Requires an API token

# %%
sampler = EmbeddingComposite(DWaveSampler())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-68bafc2bd515> in <module>
# ----> 1 sampler = EmbeddingComposite(DWaveSampler())
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/dwave/system/samplers/dwave_sampler.py in __init__(self, failover, retry_interval, **config)
#     140         defaults.update(solver=dict(order_by='-num_active_qubits'))
#     141
# --> 142         self.client = Client.from_config(**config)
#     143         self.solver = self.client.get_solver()
#     144
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/dwave/cloud/client.py in from_config(cls, config_file, profile, client, **kwargs)
#     342
#     343         logger.debug("Creating %s.Client() with: %r", _client, config)
# --> 344         return _clients[_client](**config)
#     345
#     346     @dispatches_events('client_init')
#
# ...

# %% [markdown]
# # 4. Solve the problem

# %%
sampleset = sampler.sample_qubo(Q, chain_strength = 8, num_reads=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ada0b916cb49> in <module>
# ----> 1 sampleset = sampler.sample_qubo(Q, chain_strength = 8, num_reads=100)
#
# NameError: name 'sampler' is not defined

# %% [markdown]
# # Bonus - examine the results with the inspector

# %%
inspector.show(sampleset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-85f72532119e> in <module>
# ----> 1 inspector.show(sampleset)
#
# NameError: name 'sampleset' is not defined

# %% [markdown]
# # 5. Interpret the results - print the results

# %%
print(sampleset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-40cc0dbc4dbf> in <module>
# ----> 1 print(sampleset)
#
# NameError: name 'sampleset' is not defined

# %% [markdown]
# Done!
